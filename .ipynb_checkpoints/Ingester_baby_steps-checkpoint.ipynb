# %% [markdown]
# # Data Ingester
#     Port:7497
#     Client id: 35

# %% [markdown]
# # 1 Basics Concept

# %% [markdown]
# ## 1.1 OOPS

# %%
import math

# %%
def cal_area(rad):
    return 3.14*rad*rad

print(cal_area(10))
# Out:
# 314.0

# %%
class Employee:
    def __init__(self, name="Ram",emp_id="god",exp=6,dept="r&d"): #magic fucntion executed automatically
        self.name=name
        self.emp_id=emp_id
        self.exp=exp
        self.dept=dept
        print("Employee:",self.name,"is created")
    
    def salary(self):
        if self.exp>5 and self.dept=="r&d":
            self.salary=8
        else:
            self.salary=2
        print("Salary for Employee:",self.name,"is calculated")
        
    def disc(self):
        print("Name:",self.name,
              "Id:",self.emp_id,
              "Exp:",self.exp,
              "Dept:",self.dept,
              "Salary:", self.salary)
emp1=Employee()
emp1.salary()
emp1.disc()
# Out:
# Employee: Ram is created
# Salary for Employee: Ram is calculated
# Name: Ram Id: god Exp: 6 Dept: r&d Salary: 8

# %% [markdown]
# ## 1.2. Inheritance

# %%
class Sub_emp(Employee):
    def __init__(self, name="Ram",emp_id="god",exp=6,dept="r&d", sub_id="great"):
        super(Sub_emp,self).__init__(name, emp_id, exp, dept)# All params passed to init of super for declaring
        self.sub_id=sub_id
    def salary(self):
        self.salary=self.exp*5
        print("Salary for Employee:",self.name,"is calculated")

emp2=Sub_emp()
emp2.salary()
emp2.disc()
emp2.sub_id
# Out:
# Employee: Ram is created
# Salary for Employee: Ram is calculated
# Name: Ram Id: god Exp: 6 Dept: r&d Salary: 30
# 'great'

# %% [markdown]
# ## 1.3 Threads

# %%
import threading
import numpy as np
import time

# %%
def rand_num_gen():
    for i in range(5):
        print(np.random.randint(1, 1000))
        time.sleep(1)
        
thr1=threading.Thread(target=rand_num_gen)
thr1.start()

def greetings():
    for i in range(5):
        print("Hello")
        time.sleep(1)

greetings()
# Out:
# 42Hello
#
# Hello
# 81
# Hello
# 155
# Hello
# 167
# Hello
# 534

# %% [markdown]
# ## 1.4 Daemon

# %%
import threading
import numpy as np
import time

# %%
def rand_num_gen():
    for i in range(3):
        print(i)
        time.sleep(1)
        
thr1=threading.Thread(target=rand_num_gen)
thr1.daemon=True
thr1.start()


def greetings():
    for i in range(5):
        print("Hello")
        time.sleep(1)

greetings()
# Out:
# 0Hello
#
# ReqId: 0 Historical Data Ended from 20210330  04:31:44 to 20210419  04:31:44
# 1Hello
#
# Hello2
#
# Hello
# Hello

# %% [markdown]
# ## 1.5 Event Based Threading

# %%
import threading
import numpy as np
import time

# %%
def rand_num_gen():
    for i in range(5):
        if event.is_set():
            break
        else:
            print(i)
            time.sleep(1)

event=threading.Event()

thr1=threading.Thread(target=rand_num_gen)
thr1.start()

def greetings():
    for i in range(2):
        print("Hello")
        time.sleep(1)

greetings()
event.set() ## AFter greeting event is set
# Out:
# 0
# Hello
# 1
# Hello
# 2

# %% [markdown]
# # 2. TWS API
# ## 2.1 Eclient & Ewrapper -- Conectivity Section of API

# %%
from ibapi.client import EClient     ## For Connection
from ibapi.wrapper import EWrapper   ## For Translating all low level operations in high level python

# %%
class TradingApp(EClient, EWrapper):
    def __init__(self):
        EClient.__init__(self, self) #First self belongs to slef, other belongs to wrapper class
    
    def error(self, reqId, errorCode, errorString): # Copied from wrapper.py
        print("ReqId:",reqId, "Error:",errorCode,"Message:", errorString )
        
app=TradingApp()
app.connect("127.0.0.1",7497 , clientId=1) 
app.run()

# %% [markdown]
# #### =================> Now exit by restarting kernel

# %% [markdown]
# ## 2.2 Contract Info -- Financial Instruments (Contracts) Section of API

# %%
from ibapi.client import EClient     ## For Connection
from ibapi.wrapper import EWrapper   ## For Translating all low level operations in high level python
from ibapi.contract import Contract  ## For contract as IBKR Trades around various exchanges

# %% [raw]
# ######################## Contract Class of IBKR ##########################
# class Contract(Object):
#     def __init__(self):
#         self.conId = 0
#         self.symbol = ""
#         self.secType = ""
#         self.lastTradeDateOrContractMonth = ""
#         self.strike = 0.  # float !!
#         self.right = ""
#         self.multiplier = ""
#         self.exchange = ""
#         self.primaryExchange = "" # pick an actual (ie non-aggregate) exchange that the contract trades on.  DO NOT SET TO SMART.
#         self.currency = ""
#         self.localSymbol = ""
#         self.tradingClass = ""
#         self.includeExpired = False
#         self.secIdType = ""	  # CUSIP;SEDOL;ISIN;RIC
#         self.secId = ""
#
#         #combos
#         self.comboLegsDescrip = ""  # type: str; received in open order 14 and up for all combos
#         self.comboLegs = None     # type: list<ComboLeg>
#         self.deltaNeutralContract = None
#
#
# ######################## reqcontract comes from Eclient ##########################
# self.reqContractDetails(10004, ContractSamples.NewsFeedForQuery())

# %%
class TradingApp(EClient, EWrapper):
    def __init__(self):
        EClient.__init__(self, self) #First self belongs to slef, other belongs to wrapper class
    
    def error(self, reqId, errorCode, errorString): # Copied from wrapper.py
        print("ReqId:",reqId, "Error:",errorCode,"Message:", errorString )
        
    def contractDetails(self, reqId, contractDetails):
        print("ReqId:", reqId,
             "Contract Details:", contractDetails)

def contract_maker(symbol,sec_type="STK", exchange="NSE", currency="INR"):
    contract=Contract()
    contract.symbol = symbol
    contract.secType = sec_type
    contract.exchange =exchange
    contract.currency = currency
    return contract

app=TradingApp()
app.connect("127.0.0.1",7497 , clientId=1)

contract=contract_maker("TATAMOTOR")
app.reqContractDetails( 108,contract) ## 108 is arbirary refer to above cell for funntion

app.run()
# Out:
# unhandled exception in EReader thread
# Traceback (most recent call last):
#   File "/home/boo/Software/miniconda3/envs/quant/lib/python3.8/site-packages/ibapi-9.76.1-py3.8.egg/ibapi/reader.py", line 34, in run
#     data = self.conn.recvMsg()
#   File "/home/boo/Software/miniconda3/envs/quant/lib/python3.8/site-packages/ibapi-9.76.1-py3.8.egg/ibapi/connection.py", line 99, in recvMsg
#     buf = self._recvAllMsg()
#   File "/home/boo/Software/miniconda3/envs/quant/lib/python3.8/site-packages/ibapi-9.76.1-py3.8.egg/ibapi/connection.py", line 119, in _recvAllMsg
#     buf = self.socket.recv(4096)
# ConnectionResetError: [Errno 104] Connection reset by peer

# %% [markdown]
# #### =================> Now exit by restarting kernel

# %% [markdown]
# ## 2.3 Solving Persistant Connection using multithreading and restarting kernel

# %%
from ibapi.client import EClient     ## For Connection
from ibapi.wrapper import EWrapper   ## For Translating all low level operations in high level python
from ibapi.contract import Contract  ## For contract as IBKR Trades around various exchanges

import threading
import time

class TradingApp(EClient, EWrapper):
    def __init__(self):
        EClient.__init__(self, self) #First self belongs to slef, other belongs to wrapper class
    
    def error(self, reqId, errorCode, errorString): # Copied from wrapper.py
        print("ReqId:",reqId, "Error:",errorCode,"Message:", errorString )
        
    def contractDetails(self, reqId, contractDetails):
        print("ReqId:", reqId,
             "Contract Details:", contractDetails)


def contract_maker(symbol,sec_type="STK", exchange="NSE", currency="INR"):
    contract=Contract()
    contract.symbol = symbol
    contract.secType = sec_type
    contract.exchange =exchange
    contract.currency = currency
    return contract

def web_socket():
    app.run()

app=TradingApp()
app.connect("127.0.0.1",7497 , clientId=1)

thr1=threading.Thread(target=web_socket)
thr1.daemon=True
thr1.start()

contract=contract_maker("TATAMOTOR")
time.sleep(1)  ## Wait for Client to make conecction and then pass this to to thread for reply
app.reqContractDetails( 108,contract) ## 108 is arbirary refer to above cell for funntion
        
    
def kernel_restarter():
    from IPython.display import display_html
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)

time.sleep(5)## Waiting for app.reqContract to finish before restarting kernel.
kernel_restarter()

# %% [markdown]
# ## 2.4 Solving Persistant Connection using Event and restarting kernel

# %%
from ibapi.client import EClient     ## For Connection
from ibapi.wrapper import EWrapper   ## For Translating all low level operations in high level python
from ibapi.contract import Contract  ## For contract as IBKR Trades around various exchanges

import threading
import time

class TradingApp(EClient, EWrapper):
    def __init__(self):
        EClient.__init__(self, self) #First self belongs to slef, other belongs to wrapper class
    
    def error(self, reqId, errorCode, errorString): # Copied from wrapper.py
        print("ReqId:",reqId, "Error:",errorCode,"Message:", errorString )
        
    def contractDetails(self, reqId, contractDetails):
        print("ReqId:", reqId,
             "Contract Details:", contractDetails)


def contract_maker(symbol,sec_type="STK", exchange="NSE", currency="INR"):
    contract=Contract()
    contract.symbol = symbol
    contract.secType = sec_type
    contract.exchange =exchange
    contract.currency = currency
    return contract

def web_socket():
    app.run()
    if event.is_set():
        app.close()
    

app=TradingApp()
app.connect("127.0.0.1",7497 , clientId=1)

event=threading.Event()
thr1=threading.Thread(target=web_socket)
thr1.start()

contract=contract_maker("TATAMOTOR")
time.sleep(1)  ## Wait for Client to make conecction and then pass this to to thread for reply
app.reqContractDetails( 108,contract) ## 108 is arbirary refer to above cell for funntion
event.set()
time.sleep(5)## Waiting for app.reqContract to finish before restarting kernel.
    
    
def kernel_restarter():
    from IPython.display import display_html
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)

kernel_restarter()

# %% [markdown]
# # 3. Retriving Data
# ## 3.1. Getting Historical Data -- Historical Market Data Section of API

# %% [raw]
# void reqHistoricalData	(	int 	tickerId,
# Contract 	contract,
# string 	endDateTime,
# string 	durationStr,
# string 	barSizeSetting,
# string 	whatToShow,
# int 	useRTH,
# int 	formatDate,
# bool 	keepUpToDate,
# List< TagValue > 	chartOptions
# )
#
#
# Parameters
#
# tickerId	the request's unique identifier.
# contract	the contract for which we want to retrieve the data.
# endDateTime	request's ending time with format yyyyMMdd HH:mm:ss {TMZ}
# durationStr	the amount of time for which the data needs to be retrieved:
#     " S (seconds) - " D (days)
#     " W (weeks) - " M (months)
#     " Y (years)
# barSizeSetting	the size of the bar:
#     1 sec
#     5 secs
#     15 secs
#     30 secs
#     1 min
#     2 mins
#     3 mins
#     5 mins
#     15 mins
#     30 mins
#     1 hour
#     1 day
# whatToShow	the kind of information being retrieved:
#     TRADES
#     MIDPOINT
#     BID
#     ASK
#     BID_ASK
#     HISTORICAL_VOLATILITY
#     OPTION_IMPLIED_VOLATILITY
#     FEE_RATE
#     REBATE_RATE
# useRTH	set to 0 to obtain the data which was also generated outside of the Regular Trading Hours, set to 1 to obtain only the RTH data
# formatDate	set to 1 to obtain the bars' time as yyyyMMdd HH:mm:ss, set to 2 to obtain it like system time format in seconds
# keepUpToDate	set to True to received continuous updates on most recent bar data. If True, and endDateTime cannot be specified.

# %%
from ibapi.client import EClient     ## For Connection
from ibapi.wrapper import EWrapper   ## For Translating all low level operations in high level python
from ibapi.contract import Contract  ## For contract as IBKR Trades around various exchanges

import threading
import time

class TradingApp(EClient, EWrapper):
    def __init__(self):
        EClient.__init__(self, self) #First self belongs to slef, other belongs to wrapper class
    
    def error(self, reqId, errorCode, errorString): # Copied from wrapper.py
        print("ReqId:",reqId, "Error:",errorCode,"Message:", errorString )
        
    def contractDetails(self, reqId, contractDetails):
        print("ReqId:", reqId,
             "Contract Details:", contractDetails)
        
    def headTimestamp(self, reqId, headTimestamp):
        print("ReqId:", reqId,"Earliest data available:",headTimestamp)

    def historicalData(self, reqId:int, bar):
        print(bar)
        self.bar=bar
        
    def historicalDataEnd(self, reqId: int, start: str, end: str):
        super().historicalDataEnd(reqId, start, end)
        print("ReqId:", reqId,"Historical Data Ended","from", start, "to", end)
        
    def historicalDataUpdate(self, reqId: int, bar):
        print("HistoricalDataUpdate. ReqId:", reqId, "BarData.", bar)

    
def contract_maker(symbol,sec_type="STK", exchange="NSE", currency="INR"):
    contract=Contract()
    contract.symbol = symbol
    contract.secType = sec_type
    contract.exchange =exchange
    contract.currency = currency
    return contract

import datetime
today_date=(datetime.datetime.today().strftime("%Y%m%d %H:%M:%S"))
def history_retriver(req_id,contract,durationStr="2 D",barSizeSetting="1 day", endDateTime=today_date):
    app.reqHistoricalData(  reqId=req_id,
                            contract=contract,
                            endDateTime=endDateTime,
                            durationStr=durationStr,
                            barSizeSetting=barSizeSetting,
                            whatToShow="TRADES",
                            useRTH=1,
                            formatDate=1,
                            keepUpToDate=False,
                            chartOptions=[]
                         )

def web_socket():
    app.run()
    if event.is_set():
        app.close()
    

app=TradingApp()
app.connect("127.0.0.1",7497 , clientId=1)

event=threading.Event()
thr1=threading.Thread(target=web_socket)
thr1.start()

contract=contract_maker("TATAMOTOR")
time.sleep(1)  ## Wait for Client to make conecction and then pass this to to thread for reply

# app.reqContractDetails( 108,contract) ## 108 is arbirary refer to above cell for funntion
app.reqHeadTimeStamp(118, contract, "TRADES", 0, 1) # How old can we go for data 


########## Historical Data ###########
history_retriver(128, contract,"2 D", "1 day")

time.sleep(5)## Waiting for app.reqContract to finish before restarting kernel.                                                                                
event.set()

def kernel_restarter():
    from IPython.display import display_html
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)

kernel_restarter()

# %% [markdown]
# ## 3.2 Getting Historical Data for multiple Stock

# %%
from ibapi.client import EClient     ## For Connection
from ibapi.wrapper import EWrapper   ## For Translating all low level operations in high level python
from ibapi.contract import Contract  ## For contract as IBKR Trades around various exchanges

import threading
import time

class TradingApp(EClient, EWrapper):
    def __init__(self):
        EClient.__init__(self, self) #First self belongs to slef, other belongs to wrapper class
    
    def error(self, reqId, errorCode, errorString): # Copied from wrapper.py
        print("ReqId:",reqId, "Error:",errorCode,"Message:", errorString )
        
    def contractDetails(self, reqId, contractDetails):
        print("ReqId:", reqId,
             "Contract Details:", contractDetails)
        
    def headTimestamp(self, reqId, headTimestamp):
        print("ReqId:", reqId,"Earliest data available:",headTimestamp)

    def historicalData(self, reqId:int, bar):
        print(bar)
        self.bar=bar
        
    def historicalDataEnd(self, reqId: int, start: str, end: str):
        super().historicalDataEnd(reqId, start, end)
        print("ReqId:", reqId,"Historical Data Ended","from", start, "to", end)
        
    def historicalDataUpdate(self, reqId: int, bar):
        print("HistoricalDataUpdate. ReqId:", reqId, "BarData.", bar)

    
def contract_maker(symbol,sec_type="STK", exchange="NSE", currency="INR"):
    contract=Contract()
    contract.symbol = symbol
    contract.secType = sec_type
    contract.exchange =exchange
    contract.currency = currency
    return contract

import datetime
today_date=(datetime.datetime.today().strftime("%Y%m%d %H:%M:%S"))
def history_retriver(req_id,contract,durationStr="2 D",barSizeSetting="1 D", endDateTime=today_date):
    app.reqHistoricalData(  reqId=req_id,
                            contract=contract,
                            endDateTime=endDateTime,
                            durationStr=durationStr,
                            barSizeSetting=barSizeSetting,
                            whatToShow="TRADES",
                            useRTH=1,
                            formatDate=1,
                            keepUpToDate=False,
                            chartOptions=[]
                         )

def web_socket():
    app.run()
    if event.is_set():
        app.close()
    

app=TradingApp()
app.connect("127.0.0.1",7497 , clientId=1)

event=threading.Event()
thr1=threading.Thread(target=web_socket)
thr1.start()



########## Historical Data ############
tickers=['TATASTEEL', 'TATAPOWER', 'TATAMOTOR']
for i in range(len(tickers)):
    contract=contract_maker(tickers[i])
    time.sleep(1)  ## Wait for Client to make conecction and then pass this to to thread for reply
    history_retriver(i, contract,"2 D", "1 day")
    time.sleep(1)## Waiting for app.reqContract to finish before restarting kernel.                                                                                

event.set()

def kernel_restarter():
    from IPython.display import display_html
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)

kernel_restarter()

# %% [markdown]
# ## 3.3 Storing Data in Pandas Dataframe

# %%
from ibapi.client import EClient     ## For Connection
from ibapi.wrapper import EWrapper   ## For Translating all low level operations in high level python
from ibapi.contract import Contract  ## For contract as IBKR Trades around various exchanges

import threading
import time

import pandas as pd

class TradingApp(EClient, EWrapper):
    def __init__(self):
        EClient.__init__(self, self) #First self belongs to slef, other belongs to wrapper class
        self.data={}
        
    def error(self, reqId, errorCode, errorString): # Copied from wrapper.py
        print("ReqId:",reqId, "Error:",errorCode,"Message:", errorString )
        
    def contractDetails(self, reqId, contractDetails):
        print("ReqId:", reqId,
             "Contract Details:", contractDetails)
        
    def headTimestamp(self, reqId, headTimestamp):
        print("ReqId:", reqId,"Earliest data available:",headTimestamp)

    def historicalData(self, reqId, bar):
        if reqId not in self.data:
            self.data[reqId]=[{"date":bar.date,
                               "open":bar.open,
                               "high":bar.high,
                               "low":bar.low,
                               "close":bar.close,
                               "volume":bar.volume}]
        else:
            self.data[reqId].append({"date":bar.date,
                                       "open":bar.open,
                                       "high":bar.high,
                                       "low":bar.low,
                                       "close":bar.close,
                                       "volume":bar.volume})
        
    def historicalDataEnd(self, reqId: int, start: str, end: str):
        super().historicalDataEnd(reqId, start, end)
        print("ReqId:", reqId,"Historical Data Ended","from", start, "to", end)
        
    def historicalDataUpdate(self, reqId: int, bar):
        print("HistoricalDataUpdate. ReqId:", reqId, "BarData.", bar)

    
def contract_maker(symbol,sec_type="STK", exchange="NSE", currency="INR"):
    contract=Contract()
    contract.symbol = symbol
    contract.secType = sec_type
    contract.exchange =exchange
    contract.currency = currency
    return contract

def history_retriver(req_id,contract,from_datetime,duration="2 D",bar_size="1 day", ):
    app.reqHistoricalData(  reqId=req_id,
                            contract=contract,
                            endDateTime=from_datetime,
                            durationStr=duration,
                            barSizeSetting=bar_size,
                            whatToShow="TRADES",
                            useRTH=1,
                            formatDate=1,
                            keepUpToDate=False,
                            chartOptions=[]
                         )

def multi_historical_retriver(ticker_list,app_obj, from_datetime, duration,bar_size):
    df_dict={}
    for ticker in ticker_list:
        ix=ticker_list.index(ticker)

        contract=contract_maker(ticker)
        time.sleep(1)  ## Wait for Client to make conecction and then pass this to to thread for reply
        history_retriver(ix, contract,from_datetime, duration, bar_size, )
        time.sleep(1)## Waiting for app.reqContract to finish before restarting kernel.
        df_dict[ticker]=pd.DataFrame(app_obj.data[ix])
        time.sleep(1)
    
    return df_dict



##########  Starting App as Thread #############
def web_socket():
    app.run()
    if event.is_set():
        app.close()
    

app=TradingApp()
app.connect("127.0.0.1",7497 , clientId=1)

event=threading.Event()
thr1=threading.Thread(target=web_socket)
thr1.start()
##################################################


##########  From Datetime #############
import datetime
today_date=(datetime.datetime.today().strftime("%Y%m%d %H:%M:%S"))
########################################


########## Historical Data ############
tickers=['TATASTEEL', 'TATAPOWER', 'TATAMOTOR']

df=multi_historical_retriver(ticker_list=tickers,
                             app_obj=app, 
                             from_datetime=today_date,
                             duration="2 D",
                             bar_size="1 day",
                             )
print(df)
event.set()
########################################


def kernel_restarter():
    from IPython.display import display_html
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
kernel_restarter()

# %% [markdown]
# ## 3.4 Storing Data in CSV file
# -- /data/Ticker_Name/retrivalDate_bar_size

# %%
from ibapi.client import EClient     ## For Connection
from ibapi.wrapper import EWrapper   ## For Translating all low level operations in high level python
from ibapi.contract import Contract  ## For contract as IBKR Trades around various exchanges

import threading
import time

import pandas as pd

class TradingApp(EClient, EWrapper):
    def __init__(self):
        EClient.__init__(self, self) #First self belongs to slef, other belongs to wrapper class
        self.data={}
        
    def error(self, reqId, errorCode, errorString): # Copied from wrapper.py
        print("ReqId:",reqId, "Error:",errorCode,"Message:", errorString )
        
    def contractDetails(self, reqId, contractDetails):
        print("ReqId:", reqId,
             "Contract Details:", contractDetails)
        
    def headTimestamp(self, reqId, headTimestamp):
        print("ReqId:", reqId,"Earliest data available:",headTimestamp)

    def historicalData(self, reqId, bar):
        if reqId not in self.data:
            self.data[reqId]=[{"date":bar.date,
                               "open":bar.open,
                               "high":bar.high,
                               "low":bar.low,
                               "close":bar.close,
                               "volume":bar.volume}]
        else:
            self.data[reqId].append({"date":bar.date,
                                       "open":bar.open,
                                       "high":bar.high,
                                       "low":bar.low,
                                       "close":bar.close,
                                       "volume":bar.volume})
        
    def historicalDataEnd(self, reqId: int, start: str, end: str):
        super().historicalDataEnd(reqId, start, end)
        print("ReqId:", reqId,"Historical Data Ended","from", start, "to", end)
        
    def historicalDataUpdate(self, reqId: int, bar):
        print("HistoricalDataUpdate. ReqId:", reqId, "BarData.", bar)

    
def contract_maker(symbol,sec_type="STK", exchange="NSE", currency="INR"):
    contract=Contract()
    contract.symbol = symbol
    contract.secType = sec_type
    contract.exchange =exchange
    contract.currency = currency
    return contract

def history_retriver(req_id,contract,from_date,duration="2 D",bar_size="1 day", ):
    app.reqHistoricalData(  reqId=req_id,
                            contract=contract,
                            endDateTime=from_date,
                            durationStr=duration,
                            barSizeSetting=bar_size,
                            whatToShow="TRADES",
                            useRTH=1,
                            formatDate=1,
                            keepUpToDate=False,
                            chartOptions=[]
                         )
def data_saver(df_dict, from_date, duration, bar_size):
    for ticker in df_dict:
        
        ###### Directory ##########
        dir_name= "./Data/"
        import os
        os.makedirs(dir_name, exist_ok=True)
        ############################
        
        ##### File Name ###########
        date_str=from_date.split(" ")[0]
        file_name=ticker+"_"+date_str+"_"+duration+"_"+bar_size+".csv"
        file_name=file_name.replace(" ", "")
        file_name=dir_name+file_name
        ############################
        
        df_dict[ticker].to_csv(file_name, index=False)
        print("Data saved to:",file_name)

        
def multi_historical_retriver(ticker_list,app_obj, from_date, duration,bar_size):
    df_dict={}
    for ticker in ticker_list:
        ix=ticker_list.index(ticker)

        contract=contract_maker(ticker)
        time.sleep(1)  ## Wait for Client to make conecction and then pass this to to thread for reply
        history_retriver(ix, contract,from_date, duration, bar_size, )
        time.sleep(1)## Waiting for app.reqContract to finish before restarting kernel.
        df_dict[ticker]=pd.DataFrame(app_obj.data[ix])
        time.sleep(1)
    
    data_saver(df_dict, from_date, duration, bar_size)
    

##########  Starting App as Thread #############
def web_socket():
    app.run()
    event.wait()
    if event.is_set():
        app.close()
    

app=TradingApp()
app.connect("127.0.0.1",7497 , clientId=1)

event=threading.Event()
thr1=threading.Thread(target=web_socket)
thr1.start()
##################################################


##########  From Datetime #############
import datetime
today_date=(datetime.datetime.today().strftime("%Y%m%d %H:%M:%S"))
########################################


########## Historical Data ############
tickers=['TATASTEEL']
multi_historical_retriver(ticker_list=tickers,
                         app_obj=app, 
                         from_date=today_date,
                         duration="20 D",
                         bar_size="1 min",
                         )

event.set()
########################################


def kernel_restarter():
    from IPython.display import display_html
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
kernel_restarter()

# %% [markdown]
# ## 3.5 Ingesting CSV File to SQL

# %%
from ibapi.client import EClient     ## For Connection
from ibapi.wrapper import EWrapper   ## For Translating all low level operations in high level python
from ibapi.contract import Contract  ## For contract as IBKR Trades around various exchanges

import threading
import time

import pandas as pd

class TradingApp(EClient, EWrapper):
    def __init__(self, ticker_list):
        EClient.__init__(self, self) #First self belongs to slef, other belongs to wrapper class
        self.data={}
        self.ticker_list=ticker_list
        
        self.current_ticker="" 
        self.ix=-1
        self.df=pd.DataFrame()
        
    def error(self, reqId, errorCode, errorString): # Copied from wrapper.py
        print("ReqId:",reqId, "Error:",errorCode,"Message:", errorString )
        
    def contractDetails(self, reqId, contractDetails):
        print("ReqId:", reqId,
             "Contract Details:", contractDetails)
        
    def headTimestamp(self, reqId, headTimestamp):
        print("ReqId:", reqId,"Earliest data available:",headTimestamp)

    def historicalData(self, reqId, bar):
        print(threading.active_count() )
        if reqId not in self.data:
            self.data[reqId]=[{"date":bar.date,
                               "open":bar.open,
                               "high":bar.high,
                               "low":bar.low,
                               "close":bar.close,
                               "volume":bar.volume}]
        else:
            self.data[reqId].append({"date":bar.date,
                                       "open":bar.open,
                                       "high":bar.high,
                                       "low":bar.low,
                                       "close":bar.close,
                                       "volume":bar.volume})
            
    def historicalDataEnd(self, reqId: int, start: str, end: str):
        super().historicalDataEnd(reqId, start, end)
        print("ReqId:", reqId,"Historical Data Ended","from", start, "to", end)

        self.df=pd.DataFrame(self.data[reqId])
        self.df.to_csv(self.file_name, index=False)
        
    def historicalDataUpdate(self, reqId: int, bar):
        print("HistoricalDataUpdate. ReqId:", reqId, "BarData.", bar)

    
def contract_maker(symbol,sec_type="STK", exchange="NSE", currency="INR"):
    contract=Contract()
    contract.symbol = symbol
    contract.secType = sec_type
    contract.exchange =exchange
    contract.currency = currency
    return contract

def history_retriver(req_id,contract,from_date,duration="2 D",bar_size="1 day"):
    app.reqHistoricalData(  reqId=req_id,
                            contract=contract,
                            endDateTime=from_date,
                            durationStr=duration,
                            barSizeSetting=bar_size,
                            whatToShow="TRADES",
                            useRTH=1,
                            formatDate=1,
                            keepUpToDate=False,
                            chartOptions=[]
                         )
    time.sleep(1)
        
        

        
def multi_historical_retriver(ticker_list,app_obj, from_date, duration,bar_size):
    df_dict={}
    ###### Directory ##########
    dir_name= "./Data/"
    import os
    os.makedirs(dir_name, exist_ok=True)
    ############################

    for ticker in ticker_list:
        
        
        ##### File Name ###########
        date_str=from_date.split(" ")[0]
        file_name=ticker+"_"+date_str+"_"+duration+"_"+bar_size+".csv"
        file_name=file_name.replace(" ", "")
        file_name=dir_name+file_name
        ############################
        
        
        app_obj.current_ticker=ticker
        app_obj.file_name=file_name
        app_obj.ix=ticker_list.index(ticker)
        
        ix=ticker_list.index(ticker)

        contract=contract_maker(ticker)
        time.sleep(2)  ## Wait for Client to make conecction and then pass this to to thread for reply
        history_retriver(ix, contract,from_date, duration, bar_size)
        
def web_socket():
    app.run()

tickers=['TATAMOTOR']

app=TradingApp(tickers)
app.connect("127.0.0.1",7497 , clientId=1)

thr1=threading.Thread(target=web_socket)
thr1.daemon=True
thr1.start()

time.sleep(1)

##########  From Datetime #############
import datetime
today_date=(datetime.datetime.today().strftime("%Y%m%d %H:%M:%S"))
########################################


########## Historical Data ############
tickers=['TATAMOTOR','TATAPOWER']
multi_historical_retriver(ticker_list=tickers,
                         app_obj=app, 
                         from_date=today_date,
                         duration="20 D",
                         bar_size="1 min",
                         )

########################################


def kernel_restarter():
    from IPython.display import display_html
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
kernel_restarter()
# Out:
# ReqId: -1 Error: 2104 Message: Market data farm connection is OK:usfarm.nj
# ReqId: -1 Error: 2104 Message: Market data farm connection is OK:hfarm
# ReqId: -1 Error: 2106 Message: HMDS data farm connection is OK:euhmds
# ReqId: -1 Error: 2106 Message: HMDS data farm connection is OK:hkhmds
# ReqId: -1 Error: 2106 Message: HMDS data farm connection is OK:fundfarm
# ReqId: -1 Error: 2106 Message: HMDS data farm connection is OK:ushmds
# ReqId: -1 Error: 2158 Message: Sec-def data farm connection is OK:secdefhk
# <script>Jupyter.notebook.kernel.restart()</script>

# %% [markdown]
# ### 3.5.1 Ingesting CSV File to SQL  ----via simple lib

# %%
import pandas as pd

def csv_to_pandas(csv_file_name, bar_size):
    df=pd.read_csv(csv_file_name)
    
    long_bars=["1day","1week", "1month"]
    if bar_size in long_bars:
        df["date"]=pd.to_datetime(df["date"],format='%Y%m%d')
    else:
        df["date"]=pd.to_datetime(df["date"],format='%Y%m%d  %H:%M:%S')
    
    df.set_index("date", inplace=True)
    return df

def csv_name_to_data(file_name):
    ####### To Extarct Info from CSV file
    csv_file_name=file_name.split("/")[2]
    ticker=csv_file_name.split("_")[0]
    bar_size=csv_file_name.split("_")[3].split(".")[0]
    tabel_name=ticker+"_"+bar_size
    tabel_name=tabel_name.lower()
    return  tabel_name, bar_size


def sql_ingester(data_dir, overwrite=False):
    
    import sqlalchemy
    from sqlalchemy import Table, Column, Integer, String, MetaData, DateTime, Float
    engine = sqlalchemy.create_engine('postgresql://krh:krh@123@localhost:5432/krh')
    
    
    ######### Csv Part #####
    import glob
    csv_list=glob.glob(data_dir+"/*")
    ########################    
    
    ##### Sql Part #######
    for file_name in csv_list:

        #### Extracting Info #########
        table_name, bar_size=csv_name_to_data(file_name)
        df=csv_to_pandas(file_name, bar_size)
        ##################################

        
        meta = MetaData()
        tick_table = Table(
        table_name, meta, 
        Column('date', DateTime, primary_key = True), 
        Column('open', Float),
        Column('high', Float),
        Column('low', Float),
        Column('close', Float),
        Column('volume', Float),
      )
        if table_name in engine.table_names():
            print(table_name,":")
            if overwrite:
                print("Table exist, deleting this and creating new table.")
                tick_table.drop(engine)
                tick_table.create(engine)
                df.to_sql(table_name, engine, if_exists='append', chunksize=5000, method='multi')
                print("Done")
            else:
                print("Table exist, updating record.")
                old_df=pd.read_sql_table(table_name,engine, index_col="date")
                df=df[~df.index.isin(old_df.index)]
                df.to_sql(table_name, engine, if_exists='append', chunksize=5000, method='multi')
                print("Done")
        else:
            print("Table does not exist, creating one.")
            tick_table.create(engine)
            df.to_sql(table_name, engine, if_exists='append', chunksize=5000, method='multi')
            print("Done")
            
     
    return df

data_dir="./Data"
df=sql_ingester(data_dir, False)
# Out:
# tatamotor_1day :
# Table exist, updating record.
# Done
# tatasteel_1min :
# Table exist, updating record.
# Done
# tatasteel_1min :
# Table exist, updating record.
# Done
# tatapower_1day :
# Table exist, updating record.
# Done

# %% [markdown]
# ## 3.6  Final Code For CSV Retrival and SQL Upload

# %%
def csv_ingester(ticker_list,from_date,duration,bar_size,host='127.0.0.1', port=7497, clientId=23):
    from ibapi.client import EClient     ## For Connection
    from ibapi.wrapper import EWrapper   ## For Translating all low level operations in high level python
    from ibapi.contract import Contract  ## For contract as IBKR Trades around various exchanges

    import threading
    import time

    import pandas as pd

    class TradingApp(EClient, EWrapper):
        def __init__(self):
            EClient.__init__(self, self) #First self belongs to slef, other belongs to wrapper class
            self.data={}

        def error(self, reqId, errorCode, errorString): # Copied from wrapper.py
            print("ReqId:",reqId, "Error:",errorCode,"Message:", errorString )

        def contractDetails(self, reqId, contractDetails):
            print("ReqId:", reqId,
                 "Contract Details:", contractDetails)

        def headTimestamp(self, reqId, headTimestamp):
            print("ReqId:", reqId,"Earliest data available:",headTimestamp)

        def historicalData(self, reqId, bar):
            if reqId not in self.data:
                self.data[reqId]=[{"date":bar.date,
                                   "open":bar.open,
                                   "high":bar.high,
                                   "low":bar.low,
                                   "close":bar.close,
                                   "volume":bar.volume}]
            else:
                self.data[reqId].append({"date":bar.date,
                                           "open":bar.open,
                                           "high":bar.high,
                                           "low":bar.low,
                                           "close":bar.close,
                                           "volume":bar.volume})

        def historicalDataEnd(self, reqId: int, start: str, end: str):
            super().historicalDataEnd(reqId, start, end)
            print("ReqId:", reqId,"Historical Data Ended","from", start, "to", end)
            event.set()


        def historicalDataUpdate(self, reqId: int, bar):
            print("HistoricalDataUpdate. ReqId:", reqId, "BarData.", bar)


    def contract_maker(symbol,sec_type="STK", exchange="NSE", currency="INR"):
        contract=Contract()
        contract.symbol = symbol
        contract.secType = sec_type
        contract.exchange =exchange
        contract.currency = currency
        return contract

    def history_retriver(req_id,contract,from_date,duration="2 D",bar_size="1 day", ):
        app.reqHistoricalData(  reqId=req_id,
                                contract=contract,
                                endDateTime=from_date,
                                durationStr=duration,
                                barSizeSetting=bar_size,
                                whatToShow="TRADES",
                                useRTH=1,
                                formatDate=1,
                                keepUpToDate=False,
                                chartOptions=[]
                             )
    def data_saver(df_dict, from_date, duration, bar_size):
        for ticker in df_dict:

            ###### Directory ##########
            dir_name= "./Data/"
            import os
            os.makedirs(dir_name, exist_ok=True)
            ############################

            ##### File Name ###########
            date_str=from_date.split(" ")[0]
            file_name=ticker+"_"+date_str+"_"+duration+"_"+bar_size+".csv"
            file_name=file_name.replace(" ", "")
            file_name=dir_name+file_name
            ############################

            df_dict[ticker].to_csv(file_name, index=False)
            print("Data saved to:",file_name)


    def multi_historical_retriver(ticker_list,app_obj, from_date, duration,bar_size):
        df_dict={}
        for ticker in ticker_list:
            event.clear()

            ix=ticker_list.index(ticker)

            contract=contract_maker(ticker)
            time.sleep(1)  ## Wait for Client to make conecction and then pass this to to thread for reply
            history_retriver(ix, contract,from_date, duration, bar_size, )
            time.sleep(1)## Waiting for app.reqContract to finish before restarting kernel.

            event.wait()

            df_dict[ticker]=pd.DataFrame(app_obj.data[ix])
            time.sleep(1)

        data_saver(df_dict, from_date, duration, bar_size)


    ##########  Starting App as Thread #############
    def websocket_con():
        app.run()

    app = TradingApp()
    app.connect(host=host, port=port, clientId=clientId) #port 4002 for ib gateway paper trading/7497 for TWS paper trading
    con_thread = threading.Thread(target=websocket_con, daemon=True)
    con_thread.start()
    time.sleep(1) # some latency added to ensure that the connection is established

    ##################################################
    event = threading.Event() 


    ########## Historical Data ############
    
    multi_historical_retriver(ticker_list=ticker_list,
                             app_obj=app, 
                             from_date=from_date,
                             duration=duration,
                             bar_size=bar_size,
                             )


    ########################################


    def kernel_restarter():
        from IPython.display import display_html
        display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
#     kernel_restarter()

# %%
########## Historical Data ############
tickers=['TATASTEEL']

##########  From Datetime #############
import datetime
today_date=(datetime.datetime.today().strftime("%Y%m%d %H:%M:%S"))

tick_duration= "2 D"
tick_bar_size= "1 day"
csv_ingester(ticker_list=tickers,
             from_date=today_date,
             duration=tick_duration,
             bar_size=tick_bar_size,
             host='127.0.0.1', 
             port=7497, 
             clientId=23)
# Out:
# ReqId: 0 Error: 504 Message: Not connected

# %% [markdown]
# ### 3.6.1 Final code fro CSV TO SQL

# %%
import pandas as pd

def csv_to_pandas(csv_file_name, bar_size):
    df=pd.read_csv(csv_file_name)
    
    long_bars=["1day","1week", "1month"]
    if bar_size in long_bars:
        df["date"]=pd.to_datetime(df["date"],format='%Y%m%d')
    else:
        df["date"]=pd.to_datetime(df["date"],format='%Y%m%d  %H:%M:%S')
    
    df.set_index("date", inplace=True)
    return df

def csv_name_to_data(file_name):
    ####### To Extarct Info from CSV file
    csv_file_name=file_name.split("/")[2]
    ticker=csv_file_name.split("_")[0]
    bar_size=csv_file_name.split("_")[3].split(".")[0]
    tabel_name=ticker+"_"+bar_size
    tabel_name=tabel_name.lower()
    return  tabel_name, bar_size


def sql_ingester(data_dir, engine, overwrite=False):
    
    from sqlalchemy import Table, Column, Integer, String, MetaData, DateTime, Float
    
    
    ######### Csv Part #####
    import glob
    csv_list=glob.glob(data_dir+"/*")
    ########################    
    
    ##### Sql Part #######
    for file_name in csv_list:

        #### Extracting Info #########
        table_name, bar_size=csv_name_to_data(file_name)
        df=csv_to_pandas(file_name, bar_size)
        ##################################

        
        meta = MetaData()
        tick_table = Table(
        table_name, meta, 
        Column('date', DateTime, primary_key = True), 
        Column('open', Float),
        Column('high', Float),
        Column('low', Float),
        Column('close', Float),
        Column('volume', Float),
      )
        if table_name in engine.table_names():
            print(table_name,":")
            if overwrite:
                print("Table exist, deleting this and creating new table.")
                tick_table.drop(engine)
                tick_table.create(engine)
                df.to_sql(table_name, engine, if_exists='append', chunksize=5000, method='multi')
                print("Done")
            else:
                print("Table exist, updating record.")
                old_df=pd.read_sql_table(table_name,engine, index_col="date")
                df=df[~df.index.isin(old_df.index)]
                df.to_sql(table_name, engine, if_exists='append', chunksize=5000, method='multi')
                print("Done")
        else:
            print("Table does not exist, creating one.")
            tick_table.create(engine)
            df.to_sql(table_name, engine, if_exists='append', chunksize=5000, method='multi')
            print("Done")
            
     
    return df

# %%
data_dir="./Data"

import sqlalchemy
sql_obj = sqlalchemy.create_engine('postgresql://krh:krh@123@localhost:5432/krh')
    
df=sql_ingester(data_dir, sql_obj, False)
# Out:
# tatamotor_1day :
# Table exist, updating record.
# Done
# tatasteel_1min :
# Table exist, updating record.
# Done
# tatasteel_1min :
# Table exist, updating record.
# Done
# tatapower_1day :
# Table exist, updating record.
# Done
